# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dt = pd.read_csv('loan.csv')

# %%
dt.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
dt.shape
# Out:
# (614, 13)

# %%
dt.isnull() #True=null nd False = not null
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
dt.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
(dt.isnull().sum()/dt.shape[0])*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
#overall null value 
dt.isnull().sum().sum()
# Out:
# 149

# %%
# total % od null value is 
(dt.isnull().sum().sum() / (dt.shape[0] * dt.shape[1])) * 100
# Out:
# 1.8667000751691305

# %%
# graph plot using matplot lib 
sns.heatmap(dt.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dt.drop(columns=['Credit_History'],inplace=True)

# %%
# graph plot using matplot lib 
sns.heatmap(dt.isnull())
plt.show # look the data Credit_History is removed from the current data set # inplace ka use kar ke ham new dataset crete nhi kar ke usi dataset me changes karte hai
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# now remove all null value from each row but be carefull regarding how much loose your raw from the dataset 
dt.dropna(inplace=True)

# %%
dt.shape
# Out:
# (523, 12)

# %%
dt.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sns.heatmap(dt.isnull())
plt.show()
